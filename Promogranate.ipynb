# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %% [markdown]
# Mounting drive to import data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Loading image from drive

# %%
#img = image.load_img("/content/drive/MyDrive/fruit dataset/training/bacterial promogranate/3.jpg")
img = image.load_img("/content/drive/MyDrive/fruit dataset/training/bacterial promegranate/3.jpg")
plt.imshow(img)

# %% [markdown]
# Reading the shape of image

# %%
#cv2.imread("/content/drive/MyDrive/fruit dataset/training/bacterial promogranate/3.jpg").shape
cv2.imread("/content/drive/MyDrive/fruit dataset/testing/bacterial promegranate/3.jpg").shape
# Out:
# (225, 400, 3)

# %%
img = image.load_img("/content/drive/MyDrive/fruit dataset/training/without bacterial promogranate/19.jpg")
plt.imshow(img)

# %% [markdown]
# Rescaling the RGB values of images

# %%
cv2.imread("/content/drive/MyDrive/fruit dataset/training/without bacterial promogranate/19.jpg").shape
# Out:
# (600, 600, 3)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %% [markdown]
# Providing datasets to nueral network with specifications for training

# %%
train_dataset = train.flow_from_directory('/content/drive/MyDrive/fruit dataset/training',
target_size = (200, 200),
batch_size = 3,
class_mode = 'binary')

validation_dataset = train.flow_from_directory('/content/drive/MyDrive/fruit dataset/validation',
target_size = (200, 200),
batch_size = 3,
class_mode = 'binary')
# Out:
# Found 26 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %% [markdown]
# Labels generated with functions

# %%
train_dataset.class_indices
# Out:
# {'bacterial promogranate': 0, 'without bacterial promogranate': 1}

# %% [markdown]
# Using CNN with max pooling and applying filters

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3), activation = 'relu', input_shape = (200, 200, 3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3), activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                    ##
                                    tf.keras.layers.Dense(1,activation = 'sigmoid'),
                                    ])

# %% [markdown]
# Compiling the model

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(learning_rate=0.001),
              metrics = ['accuracy'])

# %%
model_fit = model.fit(train_dataset,
                      steps_per_epoch = 3,
                      epochs = 15,
                      validation_data = validation_dataset)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 4s 1s/step - loss: 6.4958 - accuracy: 0.5556 - val_loss: 4.9751 - val_accuracy: 0.5769
# Epoch 2/15
# 3/3 [==============================] - 2s 883ms/step - loss: 2.3667 - accuracy: 0.4444 - val_loss: 0.7386 - val_accuracy: 0.5769
# Epoch 3/15
# 3/3 [==============================] - 4s 1s/step - loss: 0.6044 - accuracy: 0.8889 - val_loss: 1.0034 - val_accuracy: 0.5769
# Epoch 4/15
# 3/3 [==============================] - 3s 869ms/step - loss: 0.7764 - accuracy: 0.5556 - val_loss: 0.6072 - val_accuracy: 0.6154
# Epoch 5/15
# 3/3 [==============================] - 2s 853ms/step - loss: 0.5691 - accuracy: 0.7500 - val_loss: 0.6155 - val_accuracy: 0.6154
# Epoch 6/15
# 3/3 [==============================] - 3s 1s/step - loss: 0.7456 - accuracy: 0.5556 - val_loss: 0.6160 - val_accuracy: 0.6923
# Epoch 7/15
# 3/3 [==============================] - 4s 2s/step - loss: 0.7011 - accuracy: 0.7500 - val_loss: 0.5717 - val_accuracy: 0.8462
# ...

# %% [markdown]
# Training the model

# %%
dir_path = '/content/drive/MyDrive/fruit dataset/testing'

for i in os.listdir(dir_path ):
  img = image.load_img(dir_path+'//'+ i, target_size=(200,200))
  plt.imshow(img)
  plt. show()

  X = image.img_to_array(img)
  X = np. expand_dims(X,axis =0)
  images = np.vstack([X])
  val = model.predict (images)
  if val == 0:
    print("bacterial promegranate")
  else:
    print ("without bactarial pomegranate")
# Out:
# 1/1 [==============================] - 0s 119ms/step
# without bactarial pomegranate
# 1/1 [==============================] - 0s 47ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 52ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 45ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 45ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 45ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 46ms/step
# without bactarial pomegranate
# 1/1 [==============================] - 0s 44ms/step
# without bactarial pomegranate
# 1/1 [==============================] - 0s 64ms/step
# without bactarial pomegranate
# 1/1 [==============================] - 0s 67ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 72ms/step
# bacterial promegranate
# 1/1 [==============================] - 0s 76ms/step
# bacterial promegranate
# ...
